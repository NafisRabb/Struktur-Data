# %%
queue = []

queue.append("A")
queue.append("I")
queue.append("U")
queue.append("E")
queue.append("O")

print("Initial Queue")
print(queue)

print("\nElements dequeued from queue")
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))

print("\nQueue after removing elements")
print(queue)

print("\nQueue after removing element")
print(queue)
# Out:
# Initial Queue
# ['A', 'I', 'U', 'E', 'O']
#
# Elements dequeued from queue
# A
# I
# U
#
# Queue after removing elements
# ['E', 'O']
#
# Queue after removing element
# ['E', 'O']

# %%
from collections import deque

queue = deque()

queue.append("A")
queue.append("I")
queue.append("U")
queue.append("E")
queue.append("O")

print("Initial Queue")
print(queue)

print("\nElements dequeued from queue")
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print("\nQueue after removing elements")
print(queue)
# Out:
# Initial Queue
# deque(['A', 'I', 'U', 'E', 'O'])
#
# Elements dequeued from queue
# A
# I
# U
#
# Queue after removing elements
# deque(['E', 'O'])

# %%
from queue import Queue

qu = Queue(maxsize=5)

print(qu.qsize())

qu.put("A")
qu.put("I")
qu.put("U")
qu.put("E")
qu.put("O")

print("Full: ", qu.full())
print("Size: ",qu.qsize())

print("Elements dequeued from queue")
print(qu.get())
print(qu.get())
print(qu.get())

print("\nEmpty: ", qu.empty())
print("Full; ", qu.full())
# Out:
# 0
# Full:  True
# Size:  5
# Elements dequeued from queue
# A
# I
# U
#
# Empty:  False
# Full;  False

# %%
class Queue:
  def __init__(self):
    self.queue = list()

  def addtoqu(self,dataval):

   if dataval not in self.queue:
    self.queue.insert(0,dataval)
    return True
   return False

  def removefromq(self):
    if len(self.queue)>0:
      return self.queue.pop()
    return("No elements in Queue!")

  def size(self):
    return len(self,queue)


TheQueue = Queue()
print(TheQueue.addtoqu("Jan"))
print(TheQueue.addtoqu("Feb"))
print(TheQueue.addtoqu("March"))
print(TheQueue.addtoqu("April"))
print(TheQueue.size())
print(TheQueue.removefromq())
print(TheQueue.removefromq())
print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Jan
# Feb
# 2

# %%
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i  # Mengembalikan indeks jika ditemukan
    return -1

data = [10, 50, 30, 70, 80, 60, 20, 90, 40]
print(f"Linear Search: Indeks angka 70 adalah {linear_search(data, 70)}")
# Out:
# Linear Search: Indeks angka 70 adalah 3

# %%
def binary_search(arr, x):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] < x:
            low = mid + 1
        elif arr[mid] > x:
            high = mid - 1
        else:
            return mid
    return -1

data_urut = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(f"Binary Search: Indeks angka 70 adalah {binary_search(data_urut, 70)}")
# Out:
# Binary Search: Indeks angka 70 adalah 6

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

print(f"Bubble Sort: {bubble_sort([64, 34, 25, 12, 22, 11, 90])}")
# Out:
# Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

print(f"Selection Sort: {selection_sort([64, 25, 12, 22, 11])}")
# Out:
# Selection Sort: [11, 12, 22, 25, 64]

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

print(f"Insertion Sort: {insertion_sort([12, 11, 13, 5, 6])}")
# Out:
# Insertion Sort: [5, 6, 11, 12, 13]
